# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.4
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#get tfs
tf_df = read.csv('../data/external/transcription_factor_info_063020.csv',stringsAsFactor=F)
tfs = sort(tf_df[tf_df$cell_type=='Keratinocytes',"tf"])
length(tfs)
tfs
# Out:
# [1] 107
#   [1] "ATF1"    "ATF2"    "ATF3"    "ATF4"    "ATF5"    "BARX2"   "CEBPA"
#   [8] "CEBPG"   "DLX3"    "DLX3"    "DLX5"    "E2F1"    "E2F1"    "E2F3"
#  [15] "E2F4"    "E2F7"    "ELF5"    "ESRRA"   "ETS1"    "ETV4"    "FOS"
#  [22] "FOSL1"   "FOSL2"   "FOXF2"   "FOXK2"   "FOXP1"   "GRHL1"   "GRHL2"
#  [29] "HES1"    "HES2"    "HOMEZ"   "HOXA1"   "HOXA1"   "HOXC11"  "HOXC11"
#  [36] "HOXC13"  "ID3"     "IRX2"    "IRX4"    "JUN"     "JUNB"    "JUND"
#  [43] "KER2"    "KLF16"   "KLF4"    "KLF5"    "KLF5"    "LDB2"    "MAF"
#  [50] "MAFB"    "MAML3"   "NR3C1"   "OTX1"    "OVOL1"   "OVOL1"   "PBX1"
#  [57] "PBX2"    "POU1F1"  "POU2F1"  "POU2F2"  "POU2F3"  "POU2F3"  "POU3F1"
#  [64] "POU3F2"  "POU3F3"  "POU3F4"  "POU4F1"  "POU4F2"  "POU4F3"  "POU5F1"
#  [71] "POU5F1B" "POU6F1"  "POU6F2"  "PRDM1"   "PRRX1"   "RARG"    "RELB"
#  [78] "RORA"    "RUNX1"   "RUNX1"   "SMAD4"   "SOX11"   "SOX15"   "SOX6"
#  [85] "SOX7"    "SOX9"    "SP1"     "SP3"     "SP3"     "STAT1"   "STAT6"
# ...

# %%
vocab_dir = '../data/processed/fig4_modelling/tf_tf_pairs/'

# %%
list.files(vocab_dir,pattern='*vocab*')
# Out:
#  [1] "expr_Airway_loop_loop_vocab_info.csv"
#  [2] "expr_Airway_pro_pro_vocab_info.csv"
#  [3] "expr_Astrocytes_loop_loop_vocab_info.csv"
#  [4] "expr_Astrocytes_pro_pro_vocab_info.csv"
#  [5] "expr_Bladder_loop_loop_vocab_info.csv"
#  [6] "expr_Bladder_pro_pro_vocab_info.csv"
#  [7] "expr_Colon_loop_loop_vocab_info.csv"
#  [8] "expr_Colon_pro_pro_vocab_info.csv"
#  [9] "expr_Esophageal_loop_loop_vocab_info.csv"
# [10] "expr_Esophageal_pro_pro_vocab_info.csv"
# [11] "expr_GDSD6_loop_loop_vocab_info.csv"
# [12] "expr_GDSD6_pro_pro_vocab_info.csv"
# [13] "expr_GM12878_loop_loop_vocab_info.csv"
# [14] "expr_GM12878_pro_pro_vocab_info.csv"
# [15] "expr_HMEC_loop_loop_vocab_info.csv"
# [16] "expr_HMEC_pro_pro_vocab_info.csv"
# [17] "expr_Melanocytes_loop_loop_vocab_info.csv"
# [18] "expr_Melanocytes_pro_pro_vocab_info.csv"
# [19] "expr_Ovarian_loop_loop_vocab_info.csv"
# [20] "expr_Ovarian_pro_pro_vocab_info.csv"
# [21] "expr_Pancreas_loop_loop_vocab_info.csv"
# ...

# %%
read.csv(paste0(vocab_dir, 'expr_GDSD6_vocab_info.csv'))
# Out:
#       X       chr   start     stop      TSS     chr_m start_m   stop_m
# 1     1854207 chr6  136859957 136862457 MAP7    chr6  136860191 136860212
# 2     1854270 chr6  136859957 136862457 MAP7    chr6  136860329 136860338
# 3       67379 chr1   27481472  27483972 SLC9A1  chr1   27481888  27481892
# 4       67390 chr1   27481472  27483972 SLC9A1  chr1   27481907  27481911
# 5       67400 chr1   27481472  27483972 SLC9A1  chr1   27481910  27481914
# 6       67412 chr1   27481472  27483972 SLC9A1  chr1   27481922  27481926
# 7       67462 chr1   27481472  27483972 SLC9A1  chr1   27481998  27482002
# 8       67471 chr1   27481472  27483972 SLC9A1  chr1   27482019  27482029
# 9       67483 chr1   27481472  27483972 SLC9A1  chr1   27482051  27482055
# 10      67495 chr1   27481472  27483972 SLC9A1  chr1   27482075  27482079
# 11      67538 chr1   27481472  27483972 SLC9A1  chr1   27482145  27482149
# 12     160924 chr1  154155124 154157624 TPM3    chr1  154155401 154155405
# ...
