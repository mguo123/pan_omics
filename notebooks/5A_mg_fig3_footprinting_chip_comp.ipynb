# %% [markdown]
# 05/22/2020
#
# using footprinting trim

# %%
import pybedtools
import pandas as pd
import os,glob
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict,Counter

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
save_dir = '../data/processed/fig3_footprinting'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %% [markdown]
# # get chip files
# conservative peaks
# and figure out which TFs we have

# %%
chip_annon_file = '../data/raw/tf_chip/GM12878/metadata.txt'
chip_annon_df = pd.read_csv(chip_annon_file, sep='\t')
chip_annon_df = chip_annon_df[chip_annon_df['File assembly']=='hg19']
chip_annon_df = chip_annon_df[chip_annon_df['Output type'] =='conservative IDR thresholded peaks']
print(chip_annon_df.shape)
chip_annon_df = chip_annon_df[['File accession', 'Experiment target']]
chip_annon_df[['tf', 'species']] = chip_annon_df['Experiment target'].str.split('-',expand=True)
chip_annon_df['file_path'] = '../data/raw/tf_chip/GM12878/'+chip_annon_df['File accession']+'.bed.gz'
chip_annon_df.reset_index(drop=True,inplace=True)
chip_annon_df
# Out:
# (158, 56)
#     File accession Experiment target       tf species  \
# 0      ENCFF363BLT        NFYB-human     NFYB   human
# 1      ENCFF237IPT       TCF12-human    TCF12   human
# 2      ENCFF511YXY        PBX3-human     PBX3   human
# 3      ENCFF880NTF        ELF1-human     ELF1   human
# 4      ENCFF257OPZ         NBN-human      NBN   human
# ..             ...               ...      ...     ...
# 153    ENCFF752VNM      STAT5A-human   STAT5A   human
# 154    ENCFF005LCQ       ZFP36-human    ZFP36   human
# 155    ENCFF773EXP        CBFB-human     CBFB   human
# 156    ENCFF340WUW     SMARCA5-human  SMARCA5   human
# 157    ENCFF991QKE        HDGF-human     HDGF   human
#
#                                           file_path
# 0    ../data/raw/tf_chip/GM12878/ENCFF363BLT.bed.gz
# 1    ../data/raw/tf_chip/GM12878/ENCFF237IPT.bed.gz
# 2    ../data/raw/tf_chip/GM12878/ENCFF511YXY.bed.gz
# 3    ../data/raw/tf_chip/GM12878/ENCFF880NTF.bed.gz
# 4    ../data/raw/tf_chip/GM12878/ENCFF257OPZ.bed.gz
# ..                                              ...
# 153  ../data/raw/tf_chip/GM12878/ENCFF752VNM.bed.gz
# 154  ../data/raw/tf_chip/GM12878/ENCFF005LCQ.bed.gz
# 155  ../data/raw/tf_chip/GM12878/ENCFF773EXP.bed.gz
# 156  ../data/raw/tf_chip/GM12878/ENCFF340WUW.bed.gz
# 157  ../data/raw/tf_chip/GM12878/ENCFF991QKE.bed.gz
#
# [158 rows x 5 columns]

# %%
chip_tfs = set(sorted(chip_annon_df.tf))
len(chip_tfs)
# Out:
# 131

# %%
annon_df = pd.read_csv('../data/external/HOCOMOCOv11_annotation.csv',index_col=0)
annon_df[['motif_abbr','motif_info']]=annon_df['id'].str.split("_",expand=True)
annon_df_chipsel =  annon_df[annon_df.tf.isin(chip_tfs)]
print(annon_df_chipsel.shape)
annon_df_chipsel[:5]
# Out:
# (65, 4)
#                        id      tf motif_abbr       motif_info
# 8    ARNT_HUMAN.H11MO.0.B    ARNT       ARNT  HUMAN.H11MO.0.B
# 11   ATF2_HUMAN.H11MO.0.B    ATF2       ATF2  HUMAN.H11MO.0.B
# 16  BACH1_HUMAN.H11MO.0.A   BACH1      BACH1  HUMAN.H11MO.0.A
# 19   BATF_HUMAN.H11MO.0.A    BATF       BATF  HUMAN.H11MO.0.A
# 20  BC11A_HUMAN.H11MO.0.A  BCL11A      BC11A  HUMAN.H11MO.0.A

# %%
tfid_to_tf = pd.Series(annon_df_chipsel.tf.values, index=annon_df_chipsel.id.values).to_dict()

# %%
tfs_to_check = annon_df_chipsel.tf

chip_annon_df_footsel = chip_annon_df[chip_annon_df.tf.isin(tfs_to_check)]
chip_annon_df_footsel = chip_annon_df_footsel.merge(annon_df_chipsel,how='left',on='tf')
print(chip_annon_df_footsel.shape)
chip_annon_df_footsel[:5]
# Out:
# (80, 8)
#   File accession Experiment target     tf species  \
# 0    ENCFF363BLT        NFYB-human   NFYB   human
# 1    ENCFF237IPT       TCF12-human  TCF12   human
# 2    ENCFF511YXY        PBX3-human   PBX3   human
# 3    ENCFF880NTF        ELF1-human   ELF1   human
# 4    ENCFF784PEF        JUNB-human   JUNB   human
#
#                                         file_path                    id  \
# 0  ../data/raw/tf_chip/GM12878/ENCFF363BLT.bed.gz  NFYB_HUMAN.H11MO.0.A
# 1  ../data/raw/tf_chip/GM12878/ENCFF237IPT.bed.gz  HTF4_HUMAN.H11MO.0.A
# 2  ../data/raw/tf_chip/GM12878/ENCFF511YXY.bed.gz  PBX3_HUMAN.H11MO.0.A
# 3  ../data/raw/tf_chip/GM12878/ENCFF880NTF.bed.gz  ELF1_HUMAN.H11MO.0.A
# 4  ../data/raw/tf_chip/GM12878/ENCFF784PEF.bed.gz  JUNB_HUMAN.H11MO.0.A
#
#   motif_abbr       motif_info
# 0       NFYB  HUMAN.H11MO.0.A
# 1       HTF4  HUMAN.H11MO.0.A
# 2       PBX3  HUMAN.H11MO.0.A
# 3       ELF1  HUMAN.H11MO.0.A
# 4       JUNB  HUMAN.H11MO.0.A

# %%
fileacc_to_tfid = pd.Series(chip_annon_df_footsel['id'].values, index=chip_annon_df_footsel['File accession'].values).to_dict()

# %%
# sorted(Counter(chip_annon_df_footsel.tf).items(),key=lambda x:x[1],reverse=True)

# %% [markdown]
# 65 TFs to check, in 80 files multiples of tfs
# ```
# [('SRF', 3),
#  ('IRF3', 3),
#  ('TCF12', 2),
#  ('STAT1', 2),
#  ('EBF1', 2),
#  ('MYB', 2),
#  ('ZBTB33', 2),
#  ('ATF2', 2),
#  ('CTCF', 2),
#  ('ZNF143', 2),
#  ('REST', 2),
#  ('IKZF1', 2),
#  ('PAX5', 2)
#  ```

# %% [markdown]
# # Read in atac file

# %%
atac_bed = pybedtools.BedTool('../data/raw/atac/GM12878/GM12878_rep1-rep2.idr0.05.bfilt.narrowPeak').sort().merge()
len(atac_bed)
# Out:
# 57536

# %% [markdown]
# # Read in footprinting file

# %%
# %%time
foot_bed = pybedtools.BedTool('../data/interim/merged/footprinting/GM12878_merged.bed')
len(foot_bed)
# Out:
# CPU times: user 12 s, sys: 68.1 ms, total: 12 s
# Wall time: 12 s
# 1936046

# %%
foot_bed.to_dataframe()[:5]
# Out:
#   chrom   start     end                            name      score strand  \
# 0  chr1  714007  714010   KLF8_HUMAN.H11MO.0.C.pwm.trim   3.409391      -
# 1  chr1  714017  714020  PRRX1_HUMAN.H11MO.0.D.pwm.trim   3.667177      +
# 2  chr1  714024  714029   NFIA_HUMAN.H11MO.1.D.pwm.trim   9.125519      -
# 3  chr1  714025  714031  CXXC1_HUMAN.H11MO.0.D.pwm.trim   8.169519      -
# 4  chr1  714026  714034   MYBA_HUMAN.H11MO.0.D.pwm.trim  12.352455      -
#
#   thickStart
# 0          .
# 1          .
# 2          .
# 3          .
# 4          .

# %%
suffix = '.pwm.trim'
tf_ids_to_check = [x+suffix for x in annon_df_chipsel.id.values]

# %%
foot_df = foot_bed.to_dataframe()
foot_df = foot_df[foot_df.name.isin(tf_ids_to_check)]
print(foot_df.shape)
foot_df[:5]
# Out:
# (123870, 7)
#     chrom   start     end                           name      score strand  \
# 48   chr1  762958  762971  TAF1_HUMAN.H11MO.0.A.pwm.trim  11.729402      +
# 107  chr1  825921  825929  ATF2_HUMAN.H11MO.0.B.pwm.trim  10.816700      +
# 112  chr1  825941  825960  IRF3_HUMAN.H11MO.0.B.pwm.trim   9.834650      -
# 129  chr1  840218  840228  MXI1_HUMAN.H11MO.0.A.pwm.trim  10.860437      -
# 130  chr1  840221  840229   MAX_HUMAN.H11MO.0.A.pwm.trim  10.929243      -
#
#     thickStart
# 48           .
# 107          .
# 112          .
# 129          .
# 130          .

# %% [markdown]
# # get confusion matrix (2x2)
#
# Chip peak + accessible is gold standard
#
# - A = in chip(accessible) & in foot (TP)
# - B = not in chip(accessible) & in foot (FP)
# - C = in chip(accessible)  & not in foot (FN)
# - D = not in chip(accessible)  & not in foot (TN)
#
# ```
# 2x2 matrix looks like:
# A | B
# -----
# C | D
# ```

# %%
chip_annon_df_footsel[:5]
# Out:
#   File accession Experiment target     tf species  \
# 0    ENCFF363BLT        NFYB-human   NFYB   human
# 1    ENCFF237IPT       TCF12-human  TCF12   human
# 2    ENCFF511YXY        PBX3-human   PBX3   human
# 3    ENCFF880NTF        ELF1-human   ELF1   human
# 4    ENCFF784PEF        JUNB-human   JUNB   human
#
#                                         file_path                    id  \
# 0  ../data/raw/tf_chip/GM12878/ENCFF363BLT.bed.gz  NFYB_HUMAN.H11MO.0.A
# 1  ../data/raw/tf_chip/GM12878/ENCFF237IPT.bed.gz  HTF4_HUMAN.H11MO.0.A
# 2  ../data/raw/tf_chip/GM12878/ENCFF511YXY.bed.gz  PBX3_HUMAN.H11MO.0.A
# 3  ../data/raw/tf_chip/GM12878/ENCFF880NTF.bed.gz  ELF1_HUMAN.H11MO.0.A
# 4  ../data/raw/tf_chip/GM12878/ENCFF784PEF.bed.gz  JUNB_HUMAN.H11MO.0.A
#
#   motif_abbr       motif_info
# 0       NFYB  HUMAN.H11MO.0.A
# 1       HTF4  HUMAN.H11MO.0.A
# 2       PBX3  HUMAN.H11MO.0.A
# 3       ELF1  HUMAN.H11MO.0.A
# 4       JUNB  HUMAN.H11MO.0.A

# %%
# %%time
results_dict = {}
for idx, row in chip_annon_df_footsel.iterrows():
    print(idx,row.tf,row['File accession'])
    # get chip file
    chip_file = row.file_path
    chip_name = os.path.basename(chip_file).split('.bed.gz')[0]
    chip_bed = pybedtools.BedTool(chip_file).sort().merge()
    chip_atac_bed = chip_bed.intersect(atac_bed)
    # get selected footprinting
    motif_name = fileacc_to_tfid[chip_name] + suffix
    foot_df_tfsel = foot_df[foot_df.name==motif_name]
    foot_bed_tfsel = pybedtools.BedTool.from_dataframe(foot_df_tfsel).sort()
    
    num_chip_peaks = len(chip_bed)
    num_chip_atac_peaks = len(chip_atac_bed)
    num_footprints = len(foot_bed_tfsel)
    
    TP = (chip_atac_bed+foot_bed_tfsel).count() # A
    FP = (foot_bed_tfsel-chip_atac_bed).count() # B
    FN = (chip_atac_bed-foot_bed_tfsel).count() # C
    TN = foot_bed_tfsel.cat(chip_atac_bed).count() # D

    sens = TP/(TP+FN)
    spec = TN/(TN+FP)
    PPV = TP/(TP+FP)
    FDR = 1- PPV
    NPV = TN/(TN+FP)
    acc = (TP+TN)/(TP+TN+FP+FN)
    
    results_dict[row['File accession']] = {'tf': row.tf, 'tfid':row.id,
                            'num_chip_peaks':num_chip_peaks, 'num_chip_atac_peaks':num_chip_atac_peaks,'num_footprints':num_footprints,
                            'TP':TP, 'FP':FP,'FN':FN,'TN':TN,
                'sens':sens,'spec':spec,'PPV':PPV,'NPV':NPV,'FDR':FDR,'acc':acc
    }
#     z = {**x, **y}
# Out:
# 0 NFYB ENCFF363BLT
# 1 TCF12 ENCFF237IPT
# 2 PBX3 ENCFF511YXY
# 3 ELF1 ENCFF880NTF
# 4 JUNB ENCFF784PEF
# 5 ETS1 ENCFF565SXH
# 6 ELK1 ENCFF434DKI
# 7 ESRRA ENCFF077VXQ
# 8 MEF2B ENCFF006MAM
# 9 IRF4 ENCFF708VKT
# 10 STAT1 ENCFF568FPC
# 11 STAT1 ENCFF680DVR
# 12 ZEB1 ENCFF621OAS
# 13 STAT3 ENCFF494DOZ
# 14 EBF1 ENCFF382VEJ
# 15 RXRA ENCFF299YDM
# 16 KLF5 ENCFF762AZG
# 17 MXI1 ENCFF861YUL
# 18 MYB ENCFF299VKC
# 19 MYB ENCFF173YZN
# 20 TCF12 ENCFF759PVA
# 21 ZBTB33 ENCFF431XRU
# 22 BHLHE40 ENCFF006MIL
# 23 MAX ENCFF407JNK
# 24 RUNX3 ENCFF147DQK
# 25 ATF2 ENCFF049KAI
# 26 NR2C1 ENCFF538XDH
# 27 SPI1 ENCFF040ZUY
# 28 SRF ENCFF593FGJ
# 29 YY1 ENCFF294BZJ
# 30 IRF3 ENCFF742LLN
# 31 IRF3 ENCFF880CYV
# 32 E2F4 ENCFF850MAC
# 33 ATF2 ENCFF133GHG
# 34 USF1 ENCFF859GUL
# 35 CUX1 ENCFF803SFG
# 36 CTCF ENCFF963PJY
# 37 TBP ENCFF327NLV
# 38 NR2F1 ENCFF255HIR
# 39 ZNF143 ENCFF369JYP
# 40 NR2C2 ENCFF208TMB
# 41 EBF1 ENCFF736ACY
# 42 REST ENCFF936XYD
# 43 GABPA ENCFF627POZ
# 44 IKZF1 ENCFF872DIW
# 45 PAX5 ENCFF969EMZ
# 46 JUND ENCFF321KTX
# 47 IRF3 ENCFF169DMC
# 48 SRF ENCFF703TFD
# 49 PKNOX1 ENCFF618KHI
# 50 RELB ENCFF739VBA
# 51 REST ENCFF841AZX
# 52 ARNT ENCFF794KET
# 53 PAX5 ENCFF309VXL
# 54 NFATC1 ENCFF359EFT
# 55 NFIC ENCFF269LZJ
# 56 ZBTB33 ENCFF648COV
# 57 HSF1 ENCFF662JYS
# 58 MAZ ENCFF288RYL
# 59 CTCF ENCFF096AKZ
# 60 NFATC3 ENCFF498BHJ
# 61 BATF ENCFF482FJT
# 62 MEF2C ENCFF138CXP
# 63 MEF2A ENCFF811FYS
# 64 BACH1 ENCFF748WOQ
# 65 BCL11A ENCFF220QMP
# 66 TAF1 ENCFF325FCK
# 67 CEBPB ENCFF701HMB
# 68 ZNF384 ENCFF229WZB
# 69 SRF ENCFF069KRU
# 70 TBX21 ENCFF515HWO
# 71 TCF7 ENCFF817AOQ
# 72 MAFK ENCFF112CKJ
# 73 RFX5 ENCFF968KDX
# 74 IKZF1 ENCFF343VAG
# 75 ZNF143 ENCFF631JFD
# 76 CREM ENCFF642JEY
# 77 STAT5A ENCFF752VNM
# 78 CBFB ENCFF773EXP
# 79 SMARCA5 ENCFF340WUW
# CPU times: user 19.9 s, sys: 4.1 s, total: 24 s
# Wall time: 42 s

# %%
result_df = pd.DataFrame.from_dict(results_dict,orient='index')
result_df
# Out:
#                   tf                   tfid  num_chip_peaks  \
# ENCFF363BLT     NFYB   NFYB_HUMAN.H11MO.0.A            7296
# ENCFF237IPT    TCF12   HTF4_HUMAN.H11MO.0.A           11138
# ENCFF511YXY     PBX3   PBX3_HUMAN.H11MO.0.A            3170
# ENCFF880NTF     ELF1   ELF1_HUMAN.H11MO.0.A           29061
# ENCFF784PEF     JUNB   JUNB_HUMAN.H11MO.0.A           28691
# ...              ...                    ...             ...
# ENCFF631JFD   ZNF143  ZN143_HUMAN.H11MO.0.A           11744
# ENCFF642JEY     CREM   CREM_HUMAN.H11MO.0.C           26154
# ENCFF752VNM   STAT5A  STA5A_HUMAN.H11MO.0.A            8373
# ENCFF773EXP     CBFB   PEBB_HUMAN.H11MO.0.C           16609
# ENCFF340WUW  SMARCA5  SMCA5_HUMAN.H11MO.0.C           18094
#
#              num_chip_atac_peaks  num_footprints    TP    FP     FN     TN  \
# ENCFF363BLT                 4514            1640   917   566   3597   5079
# ENCFF237IPT                 8821            1646   311  1294   8510  10009
# ENCFF511YXY                 2722             929   156   763   2566   3476
# ENCFF880NTF                22523            1534  1181   271  21342  22793
# ENCFF784PEF                14527            1420   938   457  13589  14983
# ...                          ...             ...   ...   ...    ...    ...
# ENCFF631JFD                 8836             481   159   315   8677   9151
# ENCFF642JEY                21135             741   384   237  20751  21361
# ENCFF752VNM                 7700             665    80   585   7620   8285
# ENCFF773EXP                14996            4174  1596  2437  13400  17425
# ENCFF340WUW                15022             924    82   838  14940  15838
#
#                  sens      spec       PPV       NPV       FDR       acc
# ENCFF363BLT  0.203146  0.899734  0.618341  0.899734  0.381659  0.590216
# ENCFF237IPT  0.035257  0.885517  0.193769  0.885517  0.806231  0.512821
# ENCFF511YXY  0.057311  0.820005  0.169750  0.820005  0.830250  0.521764
# ENCFF880NTF  0.052435  0.988250  0.813361  0.988250  0.186639  0.525896
# ENCFF784PEF  0.064569  0.970402  0.672401  0.970402  0.327599  0.531284
# ...               ...       ...       ...       ...       ...       ...
# ENCFF631JFD  0.017995  0.966723  0.335443  0.966723  0.664557  0.508688
# ENCFF642JEY  0.018169  0.989027  0.618357  0.989027  0.381643  0.508857
# ENCFF752VNM  0.010390  0.934047  0.120301  0.934047  0.879699  0.504828
# ENCFF773EXP  0.106428  0.877303  0.395735  0.877303  0.604265  0.545671
# ENCFF340WUW  0.005459  0.949748  0.089130  0.949748  0.910870  0.502240
#
# [80 rows x 15 columns]

# %%
results_grouped = result_df.groupby('tf').agg({
    'tfid':'count',
'sens':'mean','spec':'mean','PPV':'mean','acc':'mean'
    
}).sort_values('PPV',ascending=False).reset_index()

# %%
result_df[result_df.PPV>.5].sort_values('PPV',ascending=False)
# Out:
#                   tf                   tfid  num_chip_peaks  \
# ENCFF147DQK    RUNX3  RUNX3_HUMAN.H11MO.0.A           60521
# ENCFF006MIL  BHLHE40  BHE40_HUMAN.H11MO.0.A           33025
# ENCFF880NTF     ELF1   ELF1_HUMAN.H11MO.0.A           29061
# ENCFF294BZJ      YY1   TYY1_HUMAN.H11MO.0.A           32108
# ENCFF784PEF     JUNB   JUNB_HUMAN.H11MO.0.A           28691
# ENCFF482FJT     BATF   BATF_HUMAN.H11MO.0.A           30008
# ENCFF618KHI   PKNOX1  PKNX1_HUMAN.H11MO.0.B           25453
# ENCFF642JEY     CREM   CREM_HUMAN.H11MO.0.C           26154
# ENCFF363BLT     NFYB   NFYB_HUMAN.H11MO.0.A            7296
# ENCFF096AKZ     CTCF   CTCF_HUMAN.H11MO.0.A           37803
# ENCFF040ZUY     SPI1   SPI1_HUMAN.H11MO.0.A           30175
# ENCFF859GUL     USF1   USF1_HUMAN.H11MO.0.A            6609
# ENCFF963PJY     CTCF   CTCF_HUMAN.H11MO.0.A           36465
# ENCFF133GHG     ATF2   ATF2_HUMAN.H11MO.0.B           23887
# ENCFF069KRU      SRF    SRF_HUMAN.H11MO.0.A           14724
#
#              num_chip_atac_peaks  num_footprints    TP    FP     FN     TN  \
# ENCFF147DQK                36283            1703  1445   217  34838  36498
# ENCFF006MIL                22752             732   407    63  22345  22803
# ENCFF880NTF                22523            1534  1181   271  21342  22793
# ENCFF294BZJ                24180             852   637   200  23543  24379
# ENCFF784PEF                14527            1420   938   457  13589  14983
# ENCFF482FJT                15630            1219   780   403  14850  16028
# ENCFF618KHI                15437             758   492   257  14945  15691
# ENCFF642JEY                21135             741   384   237  20751  21361
# ENCFF363BLT                 4514            1640   917   566   3597   5079
# ENCFF096AKZ                14400            3715  2058  1481  12342  15857
# ENCFF040ZUY                14742            4374  2445  1764  12297  16478
# ENCFF859GUL                 4411            1247   609   447   3802   4841
# ENCFF963PJY                14167            3715  2017  1530  12150  15675
# ENCFF133GHG                19406             921   459   376  18947  19739
# ENCFF069KRU                 7592             644   302   272   7290   7844
#
#                  sens      spec       PPV       NPV       FDR       acc
# ENCFF147DQK  0.039826  0.994090  0.869434  0.994090  0.130566  0.519781
# ENCFF006MIL  0.017889  0.997245  0.865957  0.997245  0.134043  0.508790
# ENCFF880NTF  0.052435  0.988250  0.813361  0.988250  0.186639  0.525896
# ENCFF294BZJ  0.026344  0.991863  0.761051  0.991863  0.238949  0.513054
# ENCFF784PEF  0.064569  0.970402  0.672401  0.970402  0.327599  0.531284
# ENCFF482FJT  0.049904  0.975473  0.659341  0.975473  0.340659  0.524251
# ENCFF618KHI  0.031871  0.983885  0.656876  0.983885  0.343124  0.515628
# ENCFF642JEY  0.018169  0.989027  0.618357  0.989027  0.381643  0.508857
# ENCFF363BLT  0.203146  0.899734  0.618341  0.899734  0.381659  0.590216
# ENCFF096AKZ  0.142917  0.914581  0.581520  0.914581  0.418480  0.564465
# ENCFF040ZUY  0.165853  0.903300  0.580898  0.903300  0.419102  0.573702
# ENCFF859GUL  0.138064  0.915469  0.576705  0.915469  0.423295  0.561914
# ENCFF963PJY  0.142373  0.911072  0.568650  0.911072  0.431350  0.563942
# ENCFF133GHG  0.023652  0.981307  0.549701  0.981307  0.450299  0.511070
# ENCFF069KRU  0.039779  0.966486  0.526132  0.966486  0.473868  0.518589

# %%
result_df.to_csv(os.path.join(save_dir, 'metrics_foot_chip_GM12878.csv'))

# %%
id_to_run_pairwise_on = result_df[result_df.PPV>.5].tfid.values

# %%
fig = plt.figure(figsize=(6, 12))
sns.stripplot(y = results_grouped.sort_values('spec',ascending=False).tf, x= results_grouped.sort_values('spec',ascending=False).spec)

# %%
# fig = plt.figure(figsize=(6, 12),dpi=200)
fig,ax = plt.subplots(figsize=(8, 12),dpi=200)

ax = sns.stripplot(y = results_grouped.tf, x= results_grouped.PPV)
plt.savefig(os.path.join(save_dir, 'foot_chip_PPV.pdf'),pad_inches=0.4)

# %%
sns.distplot(result_df.PPV)

# %% [markdown]
# # create confusion matrix (sscan every chip tf foot tf pair)
# - only do for good id_to_run_pairwise_on

# %%
# %%time
foot_id_to_foot_bed = {}
for foot_id in fileacc_to_tfid.values():
    # get selected footprinting
    foot_name = foot_id + suffix
    foot_df_tfsel = foot_df[foot_df.name==foot_name]#fileacc_to_tfid[chip_name]]
    foot_bed_tfsel = pybedtools.BedTool.from_dataframe(foot_df_tfsel).sort()
    foot_id_to_foot_bed[foot_id] = foot_bed_tfsel
# Out:
# CPU times: user 1.57 s, sys: 587 ms, total: 2.15 s
# Wall time: 2.83 s

# %%
len(foot_bed_tfsel)
# Out:
# 924

# %%
# %%time
results_dict_pair = {}
for idx, row in chip_annon_df_footsel.iterrows():
    if row.id not in id_to_run_pairwise_on:
        continue
    print(idx,row.tf,row['File accession'])
    # get chip file
    chip_file = row.file_path
    chip_name = os.path.basename(chip_file).split('.bed.gz')[0]
    chip_bed = pybedtools.BedTool(chip_file).sort().merge()
    chip_atac_bed = chip_bed.intersect(atac_bed)
    
    
    for foot_id in fileacc_to_tfid.values():
        if foot_id not in id_to_run_pairwise_on:
            continue
        
        # get selected footprinting      
#         foot_name = foot_id+suffix

        foot_bed_tfsel = foot_id_to_foot_bed[foot_id]
        num_chip_peaks = len(chip_bed)
        num_chip_atac_peaks = len(chip_atac_bed)
        num_footprints = len(foot_bed_tfsel)

        TP = (chip_atac_bed+foot_bed_tfsel).count() # A
        FP = (foot_bed_tfsel-chip_atac_bed).count() # B
        FN = (chip_atac_bed-foot_bed_tfsel).count() # C
        TN = foot_bed_tfsel.cat(chip_atac_bed).count() # D

        sens = TP/(TP+FN)
        spec = TN/(TN+FP)
        PPV = TP/(TP+FP)
        FDR = 1- PPV
        NPV = TN/(TN+FP)
        acc = (TP+TN)/(TP+TN+FP+FN)

        results_dict_pair[(row.id, foot_id)] = {'file_acc':chip_name,'chip_tf': row.tf,  'foot_tf':tfid_to_tf[foot_id], 'foot_id':foot_id,
#                                 'num_chip_peaks':num_chip_peaks, 'num_chip_atac_peaks':num_chip_atac_peaks,'num_footprints':num_footprints,
#                                 'TP':TP, 'FP':FP,'FN':FN,'TN':TN,
                    'sens':sens,'spec':spec,'PPV':PPV,'NPV':NPV,'FDR':FDR,'acc':acc
        }
#         print(results_dict_pair[(row.id, foot_id)])
#     z = {**x, **y}
# Out:
# 0 NFYB ENCFF363BLT
# 3 ELF1 ENCFF880NTF
# 4 JUNB ENCFF784PEF
# 22 BHLHE40 ENCFF006MIL
# 24 RUNX3 ENCFF147DQK
# 25 ATF2 ENCFF049KAI
# 27 SPI1 ENCFF040ZUY
# 28 SRF ENCFF593FGJ
# 29 YY1 ENCFF294BZJ
# 33 ATF2 ENCFF133GHG
# 34 USF1 ENCFF859GUL
# 36 CTCF ENCFF963PJY
# 48 SRF ENCFF703TFD
# 49 PKNOX1 ENCFF618KHI
# 59 CTCF ENCFF096AKZ
# 61 BATF ENCFF482FJT
# 69 SRF ENCFF069KRU
# 76 CREM ENCFF642JEY
# CPU times: user 1min 39s, sys: 9.11 s, total: 1min 49s
# Wall time: 2min 23s

# %%
pairwise_df = pd.DataFrame.from_dict(results_dict_pair,orient='index').reset_index()
pairwise_df
# Out:
#                   level_0                level_1     file_acc chip_tf  \
# 0    NFYB_HUMAN.H11MO.0.A   NFYB_HUMAN.H11MO.0.A  ENCFF363BLT    NFYB
# 1    NFYB_HUMAN.H11MO.0.A   ELF1_HUMAN.H11MO.0.A  ENCFF363BLT    NFYB
# 2    NFYB_HUMAN.H11MO.0.A   JUNB_HUMAN.H11MO.0.A  ENCFF363BLT    NFYB
# 3    NFYB_HUMAN.H11MO.0.A  BHE40_HUMAN.H11MO.0.A  ENCFF363BLT    NFYB
# 4    NFYB_HUMAN.H11MO.0.A  RUNX3_HUMAN.H11MO.0.A  ENCFF363BLT    NFYB
# ..                    ...                    ...          ...     ...
# 191  CREM_HUMAN.H11MO.0.C   USF1_HUMAN.H11MO.0.A  ENCFF642JEY    CREM
# 192  CREM_HUMAN.H11MO.0.C   CTCF_HUMAN.H11MO.0.A  ENCFF642JEY    CREM
# 193  CREM_HUMAN.H11MO.0.C  PKNX1_HUMAN.H11MO.0.B  ENCFF642JEY    CREM
# 194  CREM_HUMAN.H11MO.0.C   BATF_HUMAN.H11MO.0.A  ENCFF642JEY    CREM
# 195  CREM_HUMAN.H11MO.0.C   CREM_HUMAN.H11MO.0.C  ENCFF642JEY    CREM
#
#      foot_tf                foot_id      sens      spec       PPV       NPV  \
# 0       NFYB   NFYB_HUMAN.H11MO.0.A  0.203146  0.899734  0.618341  0.899734
# 1       ELF1   ELF1_HUMAN.H11MO.0.A  0.031015  0.809963  0.092045  0.809963
# 2       JUNB   JUNB_HUMAN.H11MO.0.A  0.010634  0.811198  0.033874  0.811198
# 3    BHLHE40  BHE40_HUMAN.H11MO.0.A  0.010855  0.884305  0.070605  0.884305
# 4      RUNX3  RUNX3_HUMAN.H11MO.0.A  0.015507  0.790198  0.041152  0.790198
# ..       ...                    ...       ...       ...       ...       ...
# 191     USF1   USF1_HUMAN.H11MO.0.A  0.018405  0.966899  0.342731  0.966899
# 192     CTCF   CTCF_HUMAN.H11MO.0.A  0.033972  0.890890  0.196389  0.890890
# 193   PKNOX1  PKNX1_HUMAN.H11MO.0.B  0.012775  0.978185  0.359043  0.978185
# 194     BATF   BATF_HUMAN.H11MO.0.A  0.025077  0.970423  0.443886  0.970423
# 195     CREM   CREM_HUMAN.H11MO.0.C  0.018169  0.989027  0.618357  0.989027
#
#           FDR       acc
# 0    0.381659  0.590216
# 1    0.907955  0.511502
# 2    0.966126  0.504037
# 3    0.929395  0.493508
# 4    0.958848  0.505615
# ..        ...       ...
# 191  0.657269  0.507877
# 192  0.803611  0.514065
# 193  0.640957  0.506199
# 194  0.556114  0.512011
# 195  0.381643  0.508857
#
# [196 rows x 12 columns]

# %%
pairwise_df.pivot('chip_tf','foot_tf',values='PPV')
# Out:
# foot_tf      ATF2      BATF   BHLHE40      CREM      CTCF      ELF1      JUNB  \
# chip_tf
# ATF2     0.549701  0.544007  0.195349  0.507645  0.150109  0.360133  0.537249
# BATF     0.187987  0.659341  0.062147  0.183844  0.051482  0.116340  0.692913
# BHLHE40  0.344910  0.257237  0.865957  0.359756  0.325581  0.459094  0.328125
# CREM     0.606742  0.443886  0.272578  0.618357  0.196389  0.481381  0.468282
# CTCF     0.071429  0.074013  0.068768  0.069767  0.581520  0.101506  0.064834
# ELF1     0.356886  0.242975  0.335582  0.365297  0.324025  0.813361  0.248939
# JUNB     0.303333  0.673142  0.070822  0.265647  0.049622  0.121331  0.672401
# NFYB     0.070078  0.038588  0.070605  0.077886  0.045393  0.092045  0.033874
# PKNOX1   0.282407  0.233637  0.173579  0.323099  0.142158  0.327946  0.245577
# RUNX3    0.517079  0.638585  0.340034  0.487294  0.377312  0.553981  0.653763
# SPI1     0.152993  0.183168  0.087518  0.153740  0.083468  0.317397  0.193069
# SRF      0.115044  0.123660  0.067723  0.113260  0.057012  0.190728  0.129852
# USF1     0.058242  0.016420  0.514071  0.050616  0.046512  0.083279  0.036646
# YY1      0.236510  0.182043  0.230892  0.249639  0.503354  0.442579  0.222380
#
# foot_tf      NFYB    PKNOX1     RUNX3      SPI1       SRF      USF1       YY1
# chip_tf
# ATF2     0.242991  0.263926  0.435974  0.358111  0.308581  0.291312  0.287915
# BATF     0.067766  0.153642  0.307692  0.225866  0.174881  0.152778  0.096357
# BHLHE40  0.336050  0.324934  0.342857  0.276294  0.210016  0.639623  0.347156
# CREM     0.419808  0.359043  0.364985  0.331547  0.279032  0.342731  0.378860
# CTCF     0.075321  0.119048  0.078097  0.076236  0.095312  0.078926  0.161972
# ELF1     0.498042  0.354582  0.263282  0.454352  0.264943  0.420578  0.482759
# JUNB     0.091243  0.165344  0.343806  0.238040  0.235008  0.161501  0.102113
# NFYB     0.618341  0.205298  0.041152  0.052112  0.062696  0.102649  0.079812
# PKNOX1   0.476882  0.656876  0.218085  0.214633  0.158400  0.248722  0.242031
# RUNX3    0.358668  0.418883  0.869434  0.538263  0.433657  0.481906  0.462085
# SPI1     0.126769  0.154557  0.200000  0.580898  0.188198  0.155556  0.146226
# SRF      0.161331  0.120370  0.130973  0.120996  0.526132  0.095395  0.134434
# USF1     0.102580  0.046174  0.031709  0.038082  0.032761  0.576705  0.069330
# YY1      0.305729  0.296689  0.197996  0.239332  0.232372  0.283232  0.761051

# %%
# fig = plt.figure()
fig,ax = plt.subplots(figsize=(8,8),dpi=200)

ax = sns.heatmap(pairwise_df.pivot('chip_tf','foot_tf',values='PPV'))
ax.set_ylim(0,len(pairwise_df.pivot('chip_tf','foot_tf',values='PPV')))#-0.5, -0.5)
plt.savefig(os.path.join(save_dir, 'foot_chip_PPV_good_pairs.pdf'),pad_inches=0.4)

# %% [markdown]
# # make atac footprinting per tissue from bam

# %%
# %%time
# results_dict_pair_all = {}
# for idx, row in chip_annon_df_footsel.iterrows():
# #     if row.id not in id_to_run_pairwise_on:
# #         continue
#     print(idx,row.tf,row['File accession'])
#     # get chip file
#     chip_file = row.file_path
#     chip_name = os.path.basename(chip_file).split('.bed.gz')[0]
#     chip_bed = pybedtools.BedTool(chip_file).sort().merge()
#     chip_atac_bed = chip_bed.intersect(atac_bed)
    
    
#     for foot_id in fileacc_to_tfid.values():
# #         if foot_id not in id_to_run_pairwise_on:
# #             continue
        
#         # get selected footprinting      
#         foot_bed_tfsel = foot_id_to_foot_bed[foot_id]

#         num_chip_peaks = len(chip_bed)
#         num_chip_atac_peaks = len(chip_atac_bed)
#         num_footprints = len(foot_bed_tfsel)

#         TP = (chip_atac_bed+foot_bed_tfsel).count() # A
#         FP = (foot_bed_tfsel-chip_atac_bed).count() # B
#         FN = (chip_atac_bed-foot_bed_tfsel).count() # C
#         TN = foot_bed_tfsel.cat(chip_atac_bed).count() # D

#         sens = TP/(TP+FN)
#         spec = TN/(TN+FP)
#         PPV = TP/(TP+FP)
#         FDR = 1- PPV
#         NPV = TN/(TN+FP)
#         acc = (TP+TN)/(TP+TN+FP+FN)

#         results_dict_pair[(chip_name,  foot_id)] = {'chip_id':row.id,'chip_tf': row.tf,  'foot_tf':tfid_to_tf[foot_id], 'foot_id':foot_id,
# #                                 'num_chip_peaks':num_chip_peaks, 'num_chip_atac_peaks':num_chip_atac_peaks,'num_footprints':num_footprints,
# #                                 'TP':TP, 'FP':FP,'FN':FN,'TN':TN,
#                     'sens':sens,'spec':spec,'PPV':PPV,'NPV':NPV,'FDR':FDR,'acc':acc
#         }
# #     z = {**x, **y}

# %%
# # testing

# chip_file = '../data/raw/tf_chip/GM12878/ENCFF363BLT.bed.gz'
# chip_name = os.path.basename(chip_file).split('.bed.gz')[0]
# chip_bed = pybedtools.BedTool(chip_file).sort().merge()
# print(len(chip_bed))

# foot_df_tfsel = foot_df[foot_df.name==fileacc_to_tfid[chip_name]]
# foot_bed_tfsel = pybedtools.BedTool.from_dataframe(foot_df_tfsel).sort()
# print(len(foot_bed_tfsel))

# %%
# TP = (chip_bed+foot_bed_tfsel).count() # A
# FP = (foot_bed_tfsel-chip_bed).count() # B
# FN = (chip_bed-foot_bed_tfsel).count() # C
# TN = foot_bed_tfsel.cat(chip_bed).count() # D

# sens = TP/(TP+FN)
# spec = TN/(TN+FP)
# PPV = TP/(TP+FP)
# FDR = 1- PPV
# NPV = TN/(TN+FP)
# acc = (TP+TN)/(TP+TN+FP+FN)

# metrics_dict={'TP':TP, 'FP':FP,'FN':FN,'TN':TN,
#                 'sens':sens,'spec':spec,'PPV':PPV,'NPV':NPV,'FDR':FDR,'acc':acc
#     }
# metrics_dict
# # foot_with_chip = foot_bed_tfsel.intersect(chip_bed,wa=True,wb=True).to_dataframe(header=None)
# # foot_with_chip.columns = [ 'chr_foot','start_foot','end_foot','tfid','score','strand','chr_chip','start_chip','end_chip']
# # print(foot_with_chip[ ['chr_chip','start_chip','end_chip']].drop_duplicates().shape[0])
# # foot_with_chip

# %%
# chip_with_foot = chip_bed.intersect(foot_bed_tfsel,wa=True,wb=True).to_dataframe(header=None)
# chip_with_foot.columns = ['chr_chip','start_chip','end_chip', 'chr_foot','start_foot','end_foot','tfid','score','strand']
# num_chip_with_foot = chip_with_foot[ ['chr_chip','start_chip','end_chip']].drop_duplicates().shape[0]
# chip_with_foot

# %%
# # the number o atac peaks that have 
# chip_atac_bed = chip_bed.intersect(atac_bed, wo=True, sorted=True, f=0.5,names='atac').merge()
# print(len(chip_atac_bed))
# chip_atac_df = chip_atac_bed.to_dataframe(header=None)
# chip_atac_df

# %% [markdown]
# # B. motif scan
#
# added 05/26/2020

# %%
# %%time
foot_df = pybedtools.BedTool('../data/raw/motif_scan/GM12878_mpbs.bed').to_dataframe()
foot_df = foot_df[foot_df.name.isin(tf_ids_to_check)]

print(foot_df.shape)
foot_df[:5]
# Out:
# (4458458, 7)
# CPU times: user 42.3 s, sys: 4.92 s, total: 47.2 s
# Wall time: 44.2 s
#    chrom   start     end                           name      score strand  \
# 4   chr1  714122  714132  NFYB_HUMAN.H11MO.0.A.pwm.trim  16.240624      +
# 24  chr1  714097  714107  COE1_HUMAN.H11MO.0.A.pwm.trim  10.835622      -
# 68  chr1  714067  714075  CREM_HUMAN.H11MO.0.C.pwm.trim  13.165158      +
# 69  chr1  714092  714100  CREM_HUMAN.H11MO.0.C.pwm.trim  13.165158      +
# 70  chr1  714067  714075  CREM_HUMAN.H11MO.0.C.pwm.trim  13.165158      -
#
#     thickStart
# 4          NaN
# 24         NaN
# 68         NaN
# 69         NaN
# 70         NaN

# %%
suffix = '.pwm.trim'
tf_ids_to_check = [x+suffix for x in annon_df_chipsel.id.values]

# %% [markdown]
# # get confusion matrix (2x2)
#
# Chip peak + accessible is gold standard
#
# - A = in chip(accessible) & in foot (TP)
# - B = not in chip(accessible) & in foot (FP)
# - C = in chip(accessible)  & not in foot (FN)
# - D = not in chip(accessible)  & not in foot (TN)
#
# ```
# 2x2 matrix looks like:
# A | B
# -----
# C | D
# ```

# %%
# %%time
results_dict = {}
for idx, row in chip_annon_df_footsel.iterrows():
    print(idx,row.tf,row['File accession'])
    # get chip file
    chip_file = row.file_path
    chip_name = os.path.basename(chip_file).split('.bed.gz')[0]
    chip_bed = pybedtools.BedTool(chip_file).sort().merge()
    chip_atac_bed = chip_bed.intersect(atac_bed)
    # get selected footprinting
    motif_name = fileacc_to_tfid[chip_name] + suffix
    foot_df_tfsel = foot_df[foot_df.name==motif_name]
    foot_bed_tfsel = pybedtools.BedTool.from_dataframe(foot_df_tfsel).sort()
    
    num_chip_peaks = len(chip_bed)
    num_chip_atac_peaks = len(chip_atac_bed)
    num_footprints = len(foot_bed_tfsel)
    
    TP = (chip_atac_bed+foot_bed_tfsel).count() # A
    FP = (foot_bed_tfsel-chip_atac_bed).count() # B
    FN = (chip_atac_bed-foot_bed_tfsel).count() # C
    TN = foot_bed_tfsel.cat(chip_atac_bed).count() # D

    sens = TP/(TP+FN)
    spec = TN/(TN+FP)
    PPV = TP/(TP+FP)
    FDR = 1- PPV
    NPV = TN/(TN+FP)
    acc = (TP+TN)/(TP+TN+FP+FN)
    
    results_dict[row['File accession']] = {'tf': row.tf, 'tfid':row.id,
                            'num_chip_peaks':num_chip_peaks, 'num_chip_atac_peaks':num_chip_atac_peaks,'num_footprints':num_footprints,
                            'TP':TP, 'FP':FP,'FN':FN,'TN':TN,
                'sens':sens,'spec':spec,'PPV':PPV,'NPV':NPV,'FDR':FDR,'acc':acc
    }
#     z = {**x, **y}
# Out:
# 0 NFYB ENCFF363BLT
# 1 TCF12 ENCFF237IPT
# 2 PBX3 ENCFF511YXY
# 3 ELF1 ENCFF880NTF
# 4 JUNB ENCFF784PEF
# 5 ETS1 ENCFF565SXH
# 6 ELK1 ENCFF434DKI
# 7 ESRRA ENCFF077VXQ
# 8 MEF2B ENCFF006MAM
# 9 IRF4 ENCFF708VKT
# 10 STAT1 ENCFF568FPC
# 11 STAT1 ENCFF680DVR
# 12 ZEB1 ENCFF621OAS
# 13 STAT3 ENCFF494DOZ
# 14 EBF1 ENCFF382VEJ
# 15 RXRA ENCFF299YDM
# 16 KLF5 ENCFF762AZG
# 17 MXI1 ENCFF861YUL
# 18 MYB ENCFF299VKC
# 19 MYB ENCFF173YZN
# 20 TCF12 ENCFF759PVA
# 21 ZBTB33 ENCFF431XRU
# 22 BHLHE40 ENCFF006MIL
# 23 MAX ENCFF407JNK
# 24 RUNX3 ENCFF147DQK
# 25 ATF2 ENCFF049KAI
# 26 NR2C1 ENCFF538XDH
# 27 SPI1 ENCFF040ZUY
# 28 SRF ENCFF593FGJ
# 29 YY1 ENCFF294BZJ
# 30 IRF3 ENCFF742LLN
# 31 IRF3 ENCFF880CYV
# 32 E2F4 ENCFF850MAC
# 33 ATF2 ENCFF133GHG
# 34 USF1 ENCFF859GUL
# 35 CUX1 ENCFF803SFG
# 36 CTCF ENCFF963PJY
# 37 TBP ENCFF327NLV
# 38 NR2F1 ENCFF255HIR
# 39 ZNF143 ENCFF369JYP
# 40 NR2C2 ENCFF208TMB
# 41 EBF1 ENCFF736ACY
# 42 REST ENCFF936XYD
# 43 GABPA ENCFF627POZ
# 44 IKZF1 ENCFF872DIW
# 45 PAX5 ENCFF969EMZ
# 46 JUND ENCFF321KTX
# 47 IRF3 ENCFF169DMC
# 48 SRF ENCFF703TFD
# 49 PKNOX1 ENCFF618KHI
# 50 RELB ENCFF739VBA
# 51 REST ENCFF841AZX
# 52 ARNT ENCFF794KET
# 53 PAX5 ENCFF309VXL
# 54 NFATC1 ENCFF359EFT
# 55 NFIC ENCFF269LZJ
# 56 ZBTB33 ENCFF648COV
# 57 HSF1 ENCFF662JYS
# 58 MAZ ENCFF288RYL
# 59 CTCF ENCFF096AKZ
# 60 NFATC3 ENCFF498BHJ
# 61 BATF ENCFF482FJT
# 62 MEF2C ENCFF138CXP
# 63 MEF2A ENCFF811FYS
# 64 BACH1 ENCFF748WOQ
# 65 BCL11A ENCFF220QMP
# 66 TAF1 ENCFF325FCK
# 67 CEBPB ENCFF701HMB
# 68 ZNF384 ENCFF229WZB
# 69 SRF ENCFF069KRU
# 70 TBX21 ENCFF515HWO
# 71 TCF7 ENCFF817AOQ
# 72 MAFK ENCFF112CKJ
# 73 RFX5 ENCFF968KDX
# 74 IKZF1 ENCFF343VAG
# 75 ZNF143 ENCFF631JFD
# 76 CREM ENCFF642JEY
# 77 STAT5A ENCFF752VNM
# 78 CBFB ENCFF773EXP
# 79 SMARCA5 ENCFF340WUW
# CPU times: user 3min 4s, sys: 7.98 s, total: 3min 12s
# Wall time: 4min 22s

# %%
result_df = pd.DataFrame.from_dict(results_dict,orient='index')
result_df
# Out:
#                   tf                   tfid  num_chip_peaks  \
# ENCFF363BLT     NFYB   NFYB_HUMAN.H11MO.0.A            7296
# ENCFF237IPT    TCF12   HTF4_HUMAN.H11MO.0.A           11138
# ENCFF511YXY     PBX3   PBX3_HUMAN.H11MO.0.A            3170
# ENCFF880NTF     ELF1   ELF1_HUMAN.H11MO.0.A           29061
# ENCFF784PEF     JUNB   JUNB_HUMAN.H11MO.0.A           28691
# ...              ...                    ...             ...
# ENCFF631JFD   ZNF143  ZN143_HUMAN.H11MO.0.A           11744
# ENCFF642JEY     CREM   CREM_HUMAN.H11MO.0.C           26154
# ENCFF752VNM   STAT5A  STA5A_HUMAN.H11MO.0.A            8373
# ENCFF773EXP     CBFB   PEBB_HUMAN.H11MO.0.C           16609
# ENCFF340WUW  SMARCA5  SMCA5_HUMAN.H11MO.0.C           18094
#
#              num_chip_atac_peaks  num_footprints    TP     FP     FN     TN  \
# ENCFF363BLT                 4514           29186  2821  13006   1693   8236
# ENCFF237IPT                 8821           82588  2720  70562   6101  27257
# ENCFF511YXY                 2722           35669  1155  30456   1567  11028
# ENCFF880NTF                22523           41069  6148  10642  16375  25412
# ENCFF784PEF                14527           27378  4403  14288  10124  19163
# ...                          ...             ...   ...    ...    ...    ...
# ENCFF631JFD                 8836           47785  2031  36377   6805  18471
# ENCFF642JEY                21135           17995  1895   7536  19240  23271
# ENCFF752VNM                 7700           30973  1004  27029   6696  15946
# ENCFF773EXP                14996           77687  6129  52437   8867  32330
# ENCFF340WUW                15022           28447   917  24797  14105  22312
#
#                  sens      spec       PPV       NPV       FDR       acc
# ENCFF363BLT  0.624945  0.387722  0.178240  0.387722  0.821760  0.429298
# ENCFF237IPT  0.308355  0.278647  0.037117  0.278647  0.962883  0.281105
# ENCFF511YXY  0.424320  0.265837  0.036538  0.265837  0.963462  0.275596
# ENCFF880NTF  0.272965  0.704832  0.366170  0.704832  0.633830  0.538778
# ENCFF784PEF  0.303091  0.572868  0.235568  0.572868  0.764432  0.491183
# ...               ...       ...       ...       ...       ...       ...
# ENCFF631JFD  0.229855  0.336767  0.052880  0.336767  0.947120  0.321933
# ENCFF642JEY  0.089662  0.755380  0.200933  0.755380  0.799067  0.484502
# ENCFF752VNM  0.130390  0.371053  0.035815  0.371053  0.964185  0.334484
# ENCFF773EXP  0.408709  0.381398  0.104651  0.381398  0.895349  0.385504
# ENCFF340WUW  0.061044  0.473625  0.035662  0.473625  0.964338  0.373871
#
# [80 rows x 15 columns]

# %%
results_grouped = result_df.groupby('tf').agg({
    'tfid':'count',
'sens':'mean','spec':'mean','PPV':'mean','acc':'mean'
    
}).sort_values('PPV',ascending=False).reset_index()

# %%
result_df[result_df.PPV>.5].sort_values('PPV',ascending=False)
# Out:
# Empty DataFrame
# Columns: [tf, tfid, num_chip_peaks, num_chip_atac_peaks, num_footprints, TP, FP, FN, TN, sens, spec, PPV, NPV, FDR, acc]
# Index: []

# %%
result_df.to_csv(os.path.join(save_dir, 'metrics_motifscan_chip_GM12878.csv'))

# %%
id_to_run_pairwise_on = result_df[result_df.PPV>.5].tfid.values

# %%
fig = plt.figure(figsize=(6, 12))
sns.stripplot(y = results_grouped.sort_values('sens',ascending=False).tf, x= results_grouped.sort_values('sens',ascending=False).sens)

# %%
fig = plt.figure(figsize=(6, 12))
sns.stripplot(y = results_grouped.sort_values('spec',ascending=False).tf, x= results_grouped.sort_values('spec',ascending=False).spec)

# %%
# fig = plt.figure(figsize=(6, 12),dpi=200)
fig,ax = plt.subplots(figsize=(8, 12),dpi=200)

ax = sns.stripplot(y = results_grouped.tf, x= results_grouped.PPV)
plt.savefig(os.path.join(save_dir, 'motifscan_chip_PPV.pdf'),pad_inches=0.4)

# %%
sns.distplot(result_df.PPV)
